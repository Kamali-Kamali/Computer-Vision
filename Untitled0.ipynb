# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 15.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO("yolov8n.yaml")

# %%
root_dir = "/content/drive/MyDrive/ColabNotebooks/Butterfly_flower_bird_detection_yolo"

# %%
results=model.train(data=os.path.join(root_dir,'colab_file_butterfly.yaml'),epochs=400)
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
root_dir = "/content/drive/MyDrive/ColabNotebooks/Butterfly_flower_bird_detection_yolo"

# %%
from ultralytics import YOLO

# Load the trained YOLOv8 model
model = YOLO('/content/drive/MyDrive/ColabNotebooks/Butterfly_flower_bird_detection_yolo/runs/detect/train222/weights/best.pt')

# %%
results=model.val(data=os.path.join(root_dir,'colab_file_butterfly.yaml'),imgsz=640)
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,006,233 parameters, 13,065 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/ColabNotebooks/Butterfly_flower_bird_detection_yolo/data/labels/train.cache... 72 images, 0 backgrounds, 0 corrupt: 100%|██████████| 72/72 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:02<00:00,  1.68it/s]
#                    all         72        213      0.782      0.264      0.467      0.219
#              Butterfly         27         35          1      0.124      0.568       0.28
#                   Bird         37         91      0.614      0.242      0.295      0.111
#                 Flower         26         87      0.731      0.425      0.538      0.266
# Speed: 0.6ms preprocess, 22.0ms inference, 0.0ms loss, 4.2ms postprocess per image
# Results saved to runs/detect/val3

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO('/content/drive/MyDrive/ColabNotebooks/Butterfly_flower_bird_detection_yolo/runs/detect/train222/weights/best.pt')
# Run prediction on a video
results = model.predict(source='/content/0029.jpg', save=True)
# Out:
# image 1/1 /content/0029.jpg: 448x640 1 Bird, 149.1ms
# Speed: 2.9ms preprocess, 149.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict6

# %%
import os

from ultralytics import YOLO
import cv2


VIDEOS_DIR = os.path.join('.', 'videos')

video_path = os.path.join(VIDEOS_DIR, 'alpaca1.mp4')
video_path_out = '{}_out.mp4'.format(video_path)

cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

model_path = os.path.join('.', 'runs', 'detect', 'train', 'weights', 'last.pt')

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e662ff5fdf1e> in <cell line: 14>()
#      12 cap = cv2.VideoCapture(video_path)
#      13 ret, frame = cap.read()
# ---> 14 H, W, _ = frame.shape
#      15 out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))
#      16
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import cv2

# Input video file
input_path = "path_to_input_video.mp4"  # Replace with your input video path
output_path = "path_to_results.mp4"     # Path for saving the output video

# Open the input video
cap = cv2.VideoCapture(input_path)

# Check if the video was opened successfully
if not cap.isOpened():
    print(f"Error: Unable to open video file {input_path}")
    exit()

# Get input video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create VideoWriter for the output video
fourcc = cv2.VideoWriter_fourcc(*"mp4v")  # Codec for .mp4 format
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Process the video frame by frame
while True:
    ret, frame = cap.read()  # Read a frame
    if not ret:
        break  # Exit the loop if no frames are left

    # Optionally, apply any transformations or model predictions on the frame here
    # Example: Add text to the frame (optional)
    cv2.putText(frame, "Processed Frame", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Write the frame to the output video
    out.write(frame)

# Release resources
cap.release()
out.release()

print(f"Processed video saved to {output_path}")

# %%
# Predict on new images
results = model.predict(source='/content/2616637-hd_1920_1080_30fps.mp4', imgsz=640)
results.show()  # Display predictions
results.save()  # Save predictions
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/903) /content/2616637-hd_1920_1080_30fps.mp4: 384x640 1 Butterfly, 6 Flowers, 422.1ms
# video 1/1 (frame 2/903) /content/2616637-hd_1920_1080_30fps.mp4: 384x640 1 Butterfly, 6 Flowers, 238.6ms
# video 1/1 (frame 3/903) /content/2616637-hd_1920_1080_30fps.mp4: 384x640 2 Butterflys, 5 Flowers, 210.6ms
# video 1/1 (frame 4/903) /content/2616637-hd_1920_1080_30fps.mp4: 384x640 2 Butterflys, 5 Flowers, 169.1ms
# ...

# %%
# Save the annotated video
results = model.predict(source='/content/2616637-hd_1920_1080_30fps.mp4', imgsz=640)
for frame_result in results:
    frame_result.save()  # Save predictions for each frame

# After prediction, the annotated video is saved in `runs/predict/` directory.
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/903) /content/2616637-hd_1920_1080_30fps.mp4: 384x640 1 Butterfly, 6 Flowers, 308.7ms
# video 1/1 (frame 2/903) /content/2616637-hd_1920_1080_30fps.mp4: 384x640 1 Butterfly, 6 Flowers, 146.7ms
# video 1/1 (frame 3/903) /content/2616637-hd_1920_1080_30fps.mp4: 384x640 2 Butterflys, 5 Flowers, 150.7ms
# video 1/1 (frame 4/903) /content/2616637-hd_1920_1080_30fps.mp4: 384x640 2 Butterflys, 5 Flowers, 142.1ms
# ...
